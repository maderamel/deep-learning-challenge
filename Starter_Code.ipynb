# %% [markdown]
# <a href="https://colab.research.google.com/github/maderamel/deep-learning-challenge/blob/main/Starter_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df_clean = application_df.drop(columns = ["EIN", "NAME"])

# %%
# Determine the number of unique values in each column.
application_df_clean.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_counts = application_df_clean.APPLICATION_TYPE.value_counts()

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(application_counts[application_counts < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df_clean['APPLICATION_TYPE'] = application_df_clean['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df_clean['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df_clean.CLASSIFICATION.value_counts()

classification_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts[classification_counts > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classification_counts[classification_counts < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
  application_df_clean['CLASSIFICATION'] = application_df_clean['CLASSIFICATION'].replace(cls, "Other")

# Check to make sure binning was successful
application_df_clean['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df_clean = pd.get_dummies(application_df_clean, columns=['CLASSIFICATION'])

application_df_clean.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION      USE_CASE  ORGANIZATION  STATUS  \
# 0              T10       Independent    ProductDev   Association       1
# 1               T3       Independent  Preservation  Co-operative       1
# 2               T5  CompanySponsored    ProductDev   Association       1
# 3               T3  CompanySponsored  Preservation         Trust       1
# 4               T3       Independent     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL  \
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1
#
#    CLASSIFICATION_C1000  CLASSIFICATION_C1200  CLASSIFICATION_C2000  \
# 0                     1                     0                     0
# 1                     0                     0                     1
# 2                     0                     0                     0
# 3                     0                     0                     1
# 4                     1                     0                     0
#
#    CLASSIFICATION_C2100  CLASSIFICATION_C3000  CLASSIFICATION_Other
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     1                     0
# 3                     0                     0                     0
# 4                     0                     0                     0

# %%
# Split our preprocessed data into our features and target arrays
y = application_df_clean["IS_SUCCESSFUL"].values
X = application_df_clean.drop(["APPLICATION_TYPE", "AFFILIATION",	"USE_CASE",	"ORGANIZATION",	"INCOME_AMT",	"SPECIAL_CONSIDERATIONS"],1).values
0
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# <ipython-input-10-828cf769aa9f>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = application_df_clean.drop(["APPLICATION_TYPE", "AFFILIATION",	"USE_CASE",	"ORGANIZATION",	"INCOME_AMT",	"SPECIAL_CONSIDERATIONS"],1).values

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                800
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 3,261
# Trainable params: 3,261
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.0460 - accuracy: 0.9937
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0019 - accuracy: 0.9999
# Epoch 3/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.0019 - accuracy: 0.9999
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.0019 - accuracy: 0.9999
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0015 - accuracy: 0.9999
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 9.9600e-04 - accuracy: 0.9999
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0014 - accuracy: 0.9999
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 9.1004e-04 - accuracy: 0.9999
# Epoch 9/100
# 804/804 [==============================] - 3s 3ms/step - loss: 4.7741e-04 - accuracy: 1.0000
# Epoch 10/100
# 804/804 [==============================] - 2s 3ms/step - loss: 3.8125e-06 - accuracy: 1.0000
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 3.1438e-06 - accuracy: 1.0000
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 3.3182e-06 - accuracy: 1.0000
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 6.7901e-06 - accuracy: 1.0000
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0015 - accuracy: 0.9999
# Epoch 15/100
# 804/804 [==============================] - 2s 3ms/step - loss: 3.5588e-04 - accuracy: 0.9999
# Epoch 16/100
# 804/804 [==============================] - 3s 4ms/step - loss: 7.3900e-04 - accuracy: 0.9999
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 7.7392e-06 - accuracy: 1.0000
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.3927e-07 - accuracy: 1.0000
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.2162e-07 - accuracy: 1.0000
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.0844e-07 - accuracy: 1.0000
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 9.6765e-08 - accuracy: 1.0000
# Epoch 22/100
# 804/804 [==============================] - 2s 3ms/step - loss: 9.1424e-08 - accuracy: 1.0000
# Epoch 23/100
# 804/804 [==============================] - 2s 3ms/step - loss: 7.3980e-08 - accuracy: 1.0000
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 7.2347e-08 - accuracy: 1.0000
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 7.1002e-08 - accuracy: 1.0000
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 5.3177e-08 - accuracy: 1.0000
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 3.5818e-04 - accuracy: 1.0000
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 8.3095e-04 - accuracy: 1.0000
# Epoch 29/100
# 804/804 [==============================] - 3s 3ms/step - loss: 2.1352e-05 - accuracy: 1.0000
# Epoch 30/100
# 804/804 [==============================] - 2s 3ms/step - loss: 3.7667e-04 - accuracy: 1.0000
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 4.9524e-04 - accuracy: 1.0000
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.6878e-07 - accuracy: 1.0000
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.5991e-07 - accuracy: 1.0000
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.4943e-07 - accuracy: 1.0000
# Epoch 35/100
# 804/804 [==============================] - 2s 3ms/step - loss: 1.3418e-07 - accuracy: 1.0000
# Epoch 36/100
# 804/804 [==============================] - 3s 3ms/step - loss: 1.1398e-07 - accuracy: 1.0000
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 9.6687e-08 - accuracy: 1.0000
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 9.9767e-08 - accuracy: 1.0000
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 4.4238e-08 - accuracy: 1.0000
# Epoch 40/100
# 804/804 [==============================] - 2s 3ms/step - loss: 2.4582e-08 - accuracy: 1.0000
# Epoch 41/100
# 804/804 [==============================] - 2s 3ms/step - loss: 1.8436e-08 - accuracy: 1.0000
# Epoch 42/100
# 804/804 [==============================] - 3s 3ms/step - loss: 1.7008e-08 - accuracy: 1.0000
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.1459e-08 - accuracy: 1.0000
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 8.2486e-09 - accuracy: 1.0000
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 7.7490e-09 - accuracy: 1.0000
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 4.4611e-09 - accuracy: 1.0000
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 3.5697e-09 - accuracy: 1.0000
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 3.4107e-09 - accuracy: 1.0000
# Epoch 49/100
# 804/804 [==============================] - 3s 3ms/step - loss: 2.8064e-09 - accuracy: 1.0000
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 2.2462e-09 - accuracy: 1.0000
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0230e-09 - accuracy: 1.0000
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 2.0885e-09 - accuracy: 1.0000
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 2.2356e-09 - accuracy: 1.0000
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0024 - accuracy: 0.9999
# Epoch 55/100
# 804/804 [==============================] - 3s 3ms/step - loss: 4.5277e-04 - accuracy: 1.0000
# Epoch 56/100
# 804/804 [==============================] - 2s 3ms/step - loss: 2.2333e-07 - accuracy: 1.0000
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.8709e-07 - accuracy: 1.0000
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.4795e-07 - accuracy: 1.0000
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.0951e-07 - accuracy: 1.0000
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 7.7407e-08 - accuracy: 1.0000
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 5.7758e-08 - accuracy: 1.0000
# Epoch 62/100
# 804/804 [==============================] - 3s 3ms/step - loss: 3.8710e-08 - accuracy: 1.0000
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 2.7928e-08 - accuracy: 1.0000
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.7640e-08 - accuracy: 1.0000
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.2440e-08 - accuracy: 1.0000
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 9.0656e-09 - accuracy: 1.0000
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 6.7698e-09 - accuracy: 1.0000
# Epoch 68/100
# 804/804 [==============================] - 2s 3ms/step - loss: 4.8416e-09 - accuracy: 1.0000
# Epoch 69/100
# 804/804 [==============================] - 3s 3ms/step - loss: 3.4712e-09 - accuracy: 1.0000
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 2.6829e-09 - accuracy: 1.0000
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 2.4867e-09 - accuracy: 1.0000
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.8908e-09 - accuracy: 1.0000
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.6437e-09 - accuracy: 1.0000
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.5311e-09 - accuracy: 1.0000
# Epoch 75/100
# 804/804 [==============================] - 3s 3ms/step - loss: 1.4458e-09 - accuracy: 1.0000
# Epoch 76/100
# 804/804 [==============================] - 2s 3ms/step - loss: 1.1773e-09 - accuracy: 1.0000
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.1807e-09 - accuracy: 1.0000
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 3.4442e-07 - accuracy: 1.0000
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0013 - accuracy: 0.9999
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.0036 - accuracy: 0.9999
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 7.3758e-09 - accuracy: 1.0000
# Epoch 82/100
# 804/804 [==============================] - 3s 3ms/step - loss: 5.3766e-09 - accuracy: 1.0000
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 4.3576e-09 - accuracy: 1.0000
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 3.7562e-09 - accuracy: 1.0000
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 3.3675e-09 - accuracy: 1.0000
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 3.0943e-09 - accuracy: 1.0000
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 2.9081e-09 - accuracy: 1.0000
# Epoch 88/100
# 804/804 [==============================] - 2s 3ms/step - loss: 2.7225e-09 - accuracy: 1.0000
# Epoch 89/100
# 804/804 [==============================] - 3s 3ms/step - loss: 2.5748e-09 - accuracy: 1.0000
# Epoch 90/100
# 804/804 [==============================] - 2s 2ms/step - loss: 2.4261e-09 - accuracy: 1.0000
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 2.2678e-09 - accuracy: 1.0000
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 2.1033e-09 - accuracy: 1.0000
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.9459e-09 - accuracy: 1.0000
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.7700e-09 - accuracy: 1.0000
# Epoch 95/100
# 804/804 [==============================] - 2s 3ms/step - loss: 1.6314e-09 - accuracy: 1.0000
# Epoch 96/100
# 804/804 [==============================] - 2s 3ms/step - loss: 1.5039e-09 - accuracy: 1.0000
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.3904e-09 - accuracy: 1.0000
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.2997e-09 - accuracy: 1.0000
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.2345e-09 - accuracy: 1.0000
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.1973e-09 - accuracy: 1.0000

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 7.3295e-04 - accuracy: 0.9999 - 543ms/epoch - 2ms/step
# Loss: 0.0007329500513151288, Accuracy: 0.9998833537101746

# %%
# Export our model to HDF5 file
from google.colab import drive

file_path = "/content/drive/MyDrive/nn.h5"

nn.save(file_path)
